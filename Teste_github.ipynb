# %% [markdown]
# <a href="https://colab.research.google.com/github/MateusCastello/Python/blob/main/Teste_github.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Este é um teste
#
# testte de commit direto para o Github via Colaboratory

# %%
def hello():
  print("Hello world!")

hello()
# Out:
# Hello world!
