# %% [markdown]
# <h3>Introdução a POO</h3>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Heranças respeitam uma hierarquia, normalmente vindo de uma superclasse para as subclasses, que herdam todas as características das classes superiores
#
# ![image.png](attachment:image.png)
#
# A seta branca e vazia representa herança

# %% [markdown]
# <h4>Os pilares da POO</h4>
#
# ![image.png](attachment:image.png)
